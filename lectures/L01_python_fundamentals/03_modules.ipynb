# %% [markdown]
# # Modules
#
# Python takes a modular approach to tools. This means that the majority of Python's power comes from code/add-ons that are not part of the _vanilla Python installation_.
#
# These add-ons are often referred to as packages or modules.
#
# For example:
#
# - `pandas` is a package that implements the tools necessary to do
#   scalable data analysis.
# - `matplotlib` is a package that implements visualization tools.
# - `requests` and `urllib` are packages that allow Python to
#   interface with the internet.
#
#
# As we move further into the class, being able to
# access these packages will become very important.
#
# We can bring a package’s functionality into our current Python session
# by writing
#
# ```python
# import package
# ```

# %% [markdown]
# Once we have done this, any function or object from that package can
# be accessed by using `package.name`.
#
# Consider the example below:

# %%
# This is a package for dealing with your computer's system
import sys

sys.version  # information about the Python version in use
# Out:
# '3.14.2 (main, Jan 13 2026, 17:35:44) [Clang 21.1.4 ]'

# %% [markdown]
# ## Package aliases
#
# Some packages have long names (see `matplotlib`, for example) which
# makes accessing the package functionality somewhat inconvenient.
#
# To ease this burden, Python allows us to give aliases or “nicknames” to packages.
#
# ```python
# import package as p
# ```
#
# which allow us to reference functionality from the package as `p.thing_we_want` rather than `package.thing_we_want`.

# %%
import pandas as pd

# Spoiler, we will use the `pandas` package extensively in this course
pd.DataFrame.from_dict(
    {
        "city": ["Austin", "Houston", "New York"],
        "state": ["Texas", "Texas", "New York"]
    }
)
# Out:
#        city     state
# 0    Austin     Texas
# 1   Houston     Texas
# 2  New York  New York

# %% [markdown]
# Some common aliases for packages are
#
# - `import pandas as pd`
# - `import numpy as np`
# - `import matplotlib as mpl`
# - `import datetime as dt`
#
#
# While you *can* choose any name for an alias, we suggest that you stick
# to the common ones...
#
# There are at least two reasons that this helps:
#
# 1. When you share your code with other people, they will implicitly know what you are trying to do
# 2. When you interact with coding assistance tools, they are likely to use these abbreviations due to their training data.
#
# Don't fret -- The aliases will come quickly.

# %% [markdown]
# ## `math`
#
# Let's use this as a chance to explore the Python math package

# %%
import math  # Not typically aliased
